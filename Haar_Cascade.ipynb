# %% [markdown]
# pake gambar biasa

# %%
import cv2

# Load the Haar cascade classifier
classifier = cv2.CascadeClassifier("./haar_cascade/lib/python3.10/site-packages/cv2/data/haarcascade_frontalface_default.xml")

# Load the input image
image = cv2.imread('test.jpg')

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Detect objects in the image using the classifier
objects = classifier.detectMultiScale(gray_image)

# Loop through the detected objects and draw a rectangle around them
for (x, y, w, h) in objects:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
    # Crop the object from the image
    object_image = image[y:y+h, x:x+w]

    # Save the cropped object to a file
    cv2.imwrite('cropped_object.jpg', object_image)

# Show the image with the detected objects
# cv2.imshow('Objects', image)
# cv2.waitKey(0)

# %%
import matplotlib.pyplot as plt

# Show the image with the detected objects using imshow
plt.imshow(image)

# Show the plot
plt.show()

# %%
face = cv2.imread('cropped_object.jpg')

plt.imshow(face)

# %%
mouth = cv2.CascadeClassifier('./haar_cascade/lib/python3.10/site-packages/cv2/data/haarcascade_smile.xml')

# Load the input image
image2 = cv2.imread('cropped_object.jpg')

# Convert the image to grayscale
gray_image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)

# Detect objects in the image using the classifier
objects = classifier.detectMultiScale(gray_image2)

# Loop through the detected objects and draw a rectangle around them
for (x, y, w, h) in objects:
    cv2.rectangle(image2, (x, y), (x+w, y+h), (0, 0, 255), 2)
    # Crop the object from the image
    mouth_image = image[y:y+h, x:x+w]

    # Save the cropped object to a file
    cv2.imwrite('mouth.jpg', object_image)

# %%
mouth = cv2.imread('mouth.jpg')

plt.imshow(mouth)

# %% [markdown]
# pake webcam

# %%
import cv2

# Load the Haar cascade classifier
clfaassifier = cv2.CascadeClassifier('./haar_cascade/lib/python3.10/site-packages/cv2/data/haarcascade_frontalface_default.xml')

# Initialize the webcam capture object
capture = cv2.VideoCapture(0)

# Loop until the user presses 'q' to quit
while True:
    # Read the next frame from the webcam
    ret, frame = capture.read()

    # Convert the frame to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect objects in the frame using the classifier
    objects = classifier.detectMultiScale(gray_frame)

    # Loop through the detected objects and draw a rectangle around them
    for (x, y, w, h) in objects:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

    # Show the frame with the detected objects
    cv2.imshow('Objects', frame)

    # Check if the user pressed 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam capture object
capture.release()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 26
#      24     cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
#      25     for (x, y, w, h) in mouth:
# ---> 26         mouth = mouth.detectMultiScale(gray_frame)
#      27         cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
#      29 # Show the frame with the detected objects
#
# AttributeError: 'numpy.ndarray' object has no attribute 'detectMultiScale'

# %% [markdown]
# webcam with two classifiers

# %%
import cv2

# Load the Haar cascade classifiers
classifier1 = cv2.CascadeClassifier('./haar_cascade/lib/python3.10/site-packages/cv2/data/haarcascade_frontalface_default.xml')
classifier2 = cv2.CascadeClassifier('./haar_cascade/lib/python3.10/site-packages/cv2/data/haarcascade_smile.xml')

# Initialize the webcam capture object
capture = cv2.VideoCapture(0)

# Loop until the user presses 'q' to quit
while True:
    # Read the next frame from the webcam
    ret, frame = capture.read()

    # Convert the frame to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect objects using the first classifier
    objects1 = classifier1.detectMultiScale(gray_frame)

    # Loop through the detected objects and draw a rectangle around them
    for (x, y, w, h) in objects1:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

    # Detect objects using the second classifier
    objects2 = classifier2.detectMultiScale(gray_frame)

    # Loop through the detected objects and draw a rectangle around them
    for (x, y, w, h) in objects2:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

    # Show the frame with the detected objects
    cv2.imshow('Objects', frame)

    # Check if the user pressed 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam capture object
capture.release()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
